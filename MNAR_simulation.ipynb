# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from scipy.special import expit  # sigmoid
from sklearn.metrics import mean_absolute_error, mean_squared_error
import statsmodels.api as sm

sns.set(style="whitegrid")
np.random.seed(0)

plt.rcParams["pdf.fonttype"] = 42  
plt.rcParams["ps.fonttype"] = 42
PLOT_DIR = Path("./plots")

# %%
DATA_DIR = Path("./data")   
csv_files = sorted(DATA_DIR.glob("*.csv"))

def load_dataset(path: Path):
    df = pd.read_csv(path, index_col=0, header=0)
    mask = (~df.isna()).astype(int)
    return df, mask

def protein_stats(df: pd.DataFrame, mask: pd.DataFrame):
    mu = df.mean(skipna=True)
    r = 1 - mask.mean()
    stats = pd.DataFrame({"mu": mu, "r_real": r})
    stats = stats.dropna(subset=["mu"])  
    return stats

datasets = {}
missing_stats = {}
for f in csv_files:
    z, mask = load_dataset(f)
    datasets[f.stem] = {"data": z, "mask": mask}

    missing_rate = 1 - mask.values.mean()
    missing_stats[f.stem] = missing_rate

print(f"Loaded {len(datasets)} datasets.\n")

print("Missing rate per dataset:")
for name, rate in missing_stats.items():
    print(f" - {name}: {rate:.4f}")
# Out:
# Loaded 4 datasets.
#
# Missing rate per dataset:
#  - PCSHA: 0.4461
#  - PTV1: 0.6034
#  - TPD: 0.5100
#  - ZZOV: 0.3578

# %%
def fit_logistic_mu(stats: pd.DataFrame):
    y = stats["r_real"].values
    X = sm.add_constant(stats["mu"].values)
    model = sm.Logit(y, X)
    res = model.fit(disp=False)
    return res.params  # [intercept, slope]

def mnar_logistic(mu, params):
    a, b = params
    return expit(a + b * mu)

def mnar_threshold(mu, q=0.3, p_hi=0.8, p_lo=0.05):
    thr = np.quantile(mu, q)
    return np.where(mu < thr, p_hi, p_lo)

def mnar_jingwei(mu, q_low=0.1, q_high=0.6, p_low=0.8, p_high=0.2):
    t_low = np.quantile(mu, q_low)
    t_high = np.quantile(mu, q_high)
    mu = np.asarray(mu, float)
    p = np.empty_like(mu, float)
    p[mu <= t_low] = p_low
    mid = (mu > t_low) & (mu < t_high)
    p[mid] = p_low + (p_high - p_low) * (mu[mid] - t_low) / (t_high - t_low + 1e-12)
    p[mu >= t_high] = 0
    return p

# %%
def simulate_missing_on_observed(df: pd.DataFrame, mask: pd.DataFrame, p_per_protein: pd.Series):
    p = p_per_protein.reindex(mask.columns)
    sim_missing = np.zeros_like(mask, dtype=int)

    for col_idx, col in enumerate(mask.columns):
        obs_pos = np.flatnonzero(mask.iloc[:, col_idx].to_numpy() == 1)
        if obs_pos.size == 0:
            continue
        prob = p.iloc[col_idx]
        if pd.isna(prob):
            continue
        prob = float(prob)
        sim_missing[obs_pos, col_idx] = np.random.binomial(1, prob, size=obs_pos.size)

    sim_df = pd.DataFrame(sim_missing, index=mask.index, columns=mask.columns)
    r_sim = sim_df.sum() / mask.sum().replace(0, np.nan)
    return r_sim

# %%
results = []
for f in csv_files:
    print(f"\nProcessing {f.name} ...")
    df, mask = load_dataset(f)
    stats_df = protein_stats(df, mask)  

    try:
        params = fit_logistic_mu(stats_df)
        p_logit = mnar_logistic(stats_df["mu"], params)
    except Exception as e:
        print("Logistic fit failed:", e)
        p_logit = pd.Series(np.full(len(stats_df), np.nan), index=stats_df.index)

    p_thr = mnar_threshold(stats_df["mu"])
    p_jw = mnar_jingwei(stats_df["mu"])

    r_sim_logit = simulate_missing_on_observed(df, mask, pd.Series(p_logit, index=stats_df.index))
    r_sim_thr   = simulate_missing_on_observed(df, mask, pd.Series(p_thr,   index=stats_df.index))
    r_sim_jw    = simulate_missing_on_observed(df, mask, pd.Series(p_jw,    index=stats_df.index))

    r_real = stats_df["r_real"]
    def compute_metrics(pred):
        pred = pred.reindex(r_real.index)
        mask_valid = ~(r_real.isna() | pred.isna())
        rr = r_real[mask_valid]
        pp = pred[mask_valid]
        mae = mean_absolute_error(rr, pp)
        rmse = np.sqrt(mean_squared_error(rr, pp))
        return mae, rmse

    mae_logit, rmse_logit = compute_metrics(r_sim_logit)
    mae_thr,   rmse_thr   = compute_metrics(r_sim_thr)
    mae_jw,    rmse_jw    = compute_metrics(r_sim_jw)

    results.append({
        "dataset": f.stem,
        "MAE_logit": mae_logit, "RMSE_logit": rmse_logit,
        "MAE_thr": mae_thr,     "RMSE_thr": rmse_thr,
        "MAE_jw": mae_jw,       "RMSE_jw": rmse_jw,
    })

    log_mu = np.log10(stats_df["mu"])
    plt.figure(figsize=(7,5))
    plt.scatter(log_mu, r_real, s=15, alpha=0.7, label="Real missing", color="black")
    plt.scatter(log_mu, r_sim_logit, s=12, alpha=0.6, label="Logistic", color="#1f77b4")
    plt.scatter(log_mu, r_sim_thr,   s=12, alpha=0.6, label="Threshold", color="#ff7f0e")
    plt.scatter(log_mu, r_sim_jw,    s=12, alpha=0.6, label="JINGWEI", color="#2ca02c")
    plt.xlabel("log10(Protein mean intensity)")
    plt.ylabel("Missing rate")
    plt.title(f"Missing curves: {f.stem}")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Processing PCSHA.csv ...
# Processing PTV1.csv ...
# Processing TPD.csv ...
# /home/lizhaoxing/.conda/envs/jingwei/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# Processing ZZOV.csv ...
# /home/lizhaoxing/.conda/envs/jingwei/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))

# %%
res_df = pd.DataFrame(results)
if not res_df.empty:
    display(res_df)
# res_df.to_csv("MNAR_simulation_results.csv", index=False)
# Out:
#   dataset  MAE_logit  RMSE_logit   MAE_thr  RMSE_thr    MAE_jw   RMSE_jw
# 0   PCSHA   0.198878    0.255193  0.225433  0.337094  0.163916  0.239786
# 1    PTV1   0.234836    0.277994  0.342159  0.458998  0.260869  0.351195
# 2     TPD   0.282314    0.324228  0.290339  0.406450  0.218044  0.310585
# 3    ZZOV   0.320832    0.367475  0.234594  0.366110  0.234133  0.340581

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
import statsmodels.api as sm

from pathlib import Path
from scipy.special import expit
from sklearn.metrics import mean_absolute_error, mean_squared_error

# =========================
# Global settings
# =========================
sns.set(style="whitegrid")
np.random.seed(0)

# Make text editable in PDF
plt.rcParams["pdf.fonttype"] = 42
plt.rcParams["ps.fonttype"] = 42
plt.rcParams["font.family"] = "DejaVu Sans"

DATA_DIR = Path("./data")
PLOT_DIR = Path("./plots")
PLOT_DIR.mkdir(parents=True, exist_ok=True)

csv_files = sorted(DATA_DIR.glob("*.csv"))

# Number of repeated simulations per method per dataset
N_REPEATS = 30

# Error bar type: "std" or "sem"
ERRORBAR_TYPE = "std"


blue_cmap = LinearSegmentedColormap.from_list(
    "custom_blues",
    ["#f7fbff", "#c6dbef", "#4292c6", "#08519c", "#08306b"],
    N=256,
)


# =========================
# Helper functions
# =========================
def load_dataset(path: Path):
    df = pd.read_csv(path, index_col=0, header=0)
    mask = (~df.isna()).astype(int)
    return df, mask


def protein_stats(df: pd.DataFrame, mask: pd.DataFrame):
    mu = df.mean(skipna=True)
    r = 1 - mask.mean()
    stats = pd.DataFrame({"mu": mu, "r_real": r})
    stats = stats.dropna(subset=["mu"])
    return stats


def fit_logistic_mu(stats: pd.DataFrame):
    # NOTE:
    # statsmodels.Logit usually expects binary y.
    # Here y is a proportion in [0, 1], which is not ideal for Logit.
    # But I keep your original logic for consistency.
    y = stats["r_real"].values
    X = sm.add_constant(stats["mu"].values)
    model = sm.Logit(y, X)
    res = model.fit(disp=False)
    return res.params  # [intercept, slope]


def mnar_logistic(mu, params):
    a, b = params
    return expit(a + b * mu)


def mnar_threshold(mu, q=0.3, p_hi=0.8, p_lo=0.05):
    thr = np.quantile(mu, q)
    return np.where(mu < thr, p_hi, p_lo)


def mnar_jingwei(mu, q_low=0.1, q_high=0.6, p_low=0.8, p_high=0.2):
    t_low = np.quantile(mu, q_low)
    t_high = np.quantile(mu, q_high)

    mu = np.asarray(mu, dtype=float)
    p = np.empty_like(mu, dtype=float)

    p[mu <= t_low] = p_low
    mid = (mu > t_low) & (mu < t_high)
    p[mid] = p_low + (p_high - p_low) * (mu[mid] - t_low) / (t_high - t_low + 1e-12)

    # keep your original behavior
    p[mu >= t_high] = 0.0
    return p


def simulate_missing_on_observed(mask: pd.DataFrame, p_per_protein: pd.Series):
    """
    Simulate additional missingness only on originally observed entries.
    Return protein-level simulated missing rate.
    """
    p = p_per_protein.reindex(mask.columns)
    sim_missing = np.zeros_like(mask, dtype=int)

    for col_idx, col in enumerate(mask.columns):
        obs_pos = np.flatnonzero(mask.iloc[:, col_idx].to_numpy() == 1)
        if obs_pos.size == 0:
            continue

        prob = p.iloc[col_idx]
        if pd.isna(prob):
            continue

        prob = float(np.clip(prob, 0, 1))
        sim_missing[obs_pos, col_idx] = np.random.binomial(1, prob, size=obs_pos.size)

    sim_df = pd.DataFrame(sim_missing, index=mask.index, columns=mask.columns)

    # simulated protein-level missing rate among originally observed entries
    r_sim = sim_df.sum() / mask.sum().replace(0, np.nan)
    return r_sim


def compute_metrics(r_real: pd.Series, pred: pd.Series):
    pred = pred.reindex(r_real.index)
    valid = ~(r_real.isna() | pred.isna())
    rr = r_real[valid]
    pp = pred[valid]

    mae = mean_absolute_error(rr, pp)
    rmse = np.sqrt(mean_squared_error(rr, pp))
    return mae, rmse


def summarize_error(values, mode="std"):
    values = np.asarray(values, dtype=float)
    if mode == "sem":
        return np.std(values, ddof=1) / np.sqrt(len(values))
    return np.std(values, ddof=1)


def plot_missing_heatmap_grid(curve_data, methods, bins=(60, 60), cmap=blue_cmap, save_path=None):
    dataset_names = list(curve_data.keys())
    if len(dataset_names) == 0:
        print("No curve data to plot.")
        return

    n_rows = len(dataset_names)
    n_cols = len(methods)

    fig, axes = plt.subplots(
        n_rows, n_cols,
        figsize=(3.8 * n_cols, 3.1 * n_rows),
        sharex=True, sharey=True
    )

    if n_rows == 1:
        axes = np.expand_dims(axes, 0)
    if n_cols == 1:
        axes = np.expand_dims(axes, 1)

    # Global x-range for consistent axes
    all_x = np.concatenate([curve_data[name]["log10_mu"].values for name in dataset_names])
    x_min = np.nanmin(all_x)
    x_max = np.nanmax(all_x)

    last_im = None
    for i, ds in enumerate(dataset_names):
        df = curve_data[ds]
        for j, (title, col) in enumerate(methods):
            ax = axes[i][j]
            x = df["log10_mu"].values
            y = df[col].values
            valid = ~(np.isnan(x) | np.isnan(y))

            hist = ax.hist2d(
                x[valid], y[valid],
                bins=bins, cmap=cmap,
                norm=mcolors.LogNorm()
            )
            last_im = hist[3]

            if i == 0:
                ax.set_title(title)
            if j == 0:
                ax.set_ylabel(f"{ds}\nMissing rate")
            if i == n_rows - 1:
                ax.set_xlabel("log10(Protein intensity)")

            ax.set_xlim(x_min, x_max)
            ax.set_ylim(0, 1)

    if last_im is not None:
        fig.subplots_adjust(right=0.88)
        cax = fig.add_axes([0.90, 0.2, 0.02, 0.6])
        fig.colorbar(last_im, cax=cax, label="Counts")

    plt.tight_layout()
    if save_path is not None:
        plt.savefig(save_path, bbox_inches="tight")
    plt.show()


datasets = {}
missing_stats = {}

for f in csv_files:
    z, mask = load_dataset(f)
    datasets[f.stem] = {"data": z, "mask": mask}
    missing_rate = 1 - mask.values.mean()
    missing_stats[f.stem] = missing_rate

print(f"Loaded {len(datasets)} datasets.\n")
print("Missing rate per dataset:")
for name, rate in missing_stats.items():
    print(f" - {name}: {rate:.4f}")

all_results = []
curve_plot_paths = []
curve_data = {}

for f in csv_files:
    print(f"\nProcessing {f.name} ...")
    df, mask = load_dataset(f)
    stats_df = protein_stats(df, mask)

    if stats_df.empty:
        print(f"Skipping {f.stem}: no valid protein stats.")
        continue

    r_real = stats_df["r_real"]

    # Fit model-specific probability curves
    try:
        params = fit_logistic_mu(stats_df)
        p_logit = pd.Series(mnar_logistic(stats_df["mu"], params), index=stats_df.index)
    except Exception as e:
        print(f"Logistic fit failed for {f.stem}: {e}")
        p_logit = pd.Series(np.nan, index=stats_df.index)

    p_thr = pd.Series(mnar_threshold(stats_df["mu"]), index=stats_df.index)
    p_jw = pd.Series(mnar_jingwei(stats_df["mu"]), index=stats_df.index)

    # Repeated simulation for error bars
    mae_logit_list, rmse_logit_list = [], []
    mae_thr_list, rmse_thr_list = [], []
    mae_jw_list, rmse_jw_list = [], []

    # Save one representative simulation for the missing-curve figure
    r_sim_logit_rep = None
    r_sim_thr_rep = None
    r_sim_jw_rep = None

    for rep in range(N_REPEATS):
        r_sim_logit = simulate_missing_on_observed(mask, p_logit)
        r_sim_thr = simulate_missing_on_observed(mask, p_thr)
        r_sim_jw = simulate_missing_on_observed(mask, p_jw)

        if rep == 0:
            r_sim_logit_rep = r_sim_logit.copy()
            r_sim_thr_rep = r_sim_thr.copy()
            r_sim_jw_rep = r_sim_jw.copy()

        mae, rmse = compute_metrics(r_real, r_sim_logit)
        mae_logit_list.append(mae)
        rmse_logit_list.append(rmse)

        mae, rmse = compute_metrics(r_real, r_sim_thr)
        mae_thr_list.append(mae)
        rmse_thr_list.append(rmse)

        mae, rmse = compute_metrics(r_real, r_sim_jw)
        mae_jw_list.append(mae)
        rmse_jw_list.append(rmse)

    # Aggregate mean + error
    row = {
        "dataset": f.stem,

        "MAE_logit_mean": np.mean(mae_logit_list),
        "MAE_logit_err": summarize_error(mae_logit_list, ERRORBAR_TYPE),
        "RMSE_logit_mean": np.mean(rmse_logit_list),
        "RMSE_logit_err": summarize_error(rmse_logit_list, ERRORBAR_TYPE),

        "MAE_thr_mean": np.mean(mae_thr_list),
        "MAE_thr_err": summarize_error(mae_thr_list, ERRORBAR_TYPE),
        "RMSE_thr_mean": np.mean(rmse_thr_list),
        "RMSE_thr_err": summarize_error(rmse_thr_list, ERRORBAR_TYPE),

        "MAE_jw_mean": np.mean(mae_jw_list),
        "MAE_jw_err": summarize_error(mae_jw_list, ERRORBAR_TYPE),
        "RMSE_jw_mean": np.mean(rmse_jw_list),
        "RMSE_jw_err": summarize_error(rmse_jw_list, ERRORBAR_TYPE),
    }
    all_results.append(row)

    # =========================
    # Save missing-curve figure for this dataset
    # =========================
    plot_df = pd.DataFrame({
        "mu": stats_df["mu"],
        "r_real": r_real,
        "r_sim_logit": r_sim_logit_rep.reindex(r_real.index),
        "r_sim_thr": r_sim_thr_rep.reindex(r_real.index),
        "r_sim_jw": r_sim_jw_rep.reindex(r_real.index),
    }).dropna(subset=["mu"])

    # If mu can be <=0, avoid log10 issues
    plot_df = plot_df[plot_df["mu"] > 0].copy()
    plot_df["log10_mu"] = np.log10(plot_df["mu"])

    fig, ax = plt.subplots(figsize=(7, 5))

    ax.scatter(plot_df["log10_mu"], plot_df["r_real"],
               s=15, alpha=0.7, label="Real missing", color="black")
    ax.scatter(plot_df["log10_mu"], plot_df["r_sim_logit"],
               s=12, alpha=0.6, label="Logit", color="#1f77b4")
    ax.scatter(plot_df["log10_mu"], plot_df["r_sim_thr"],
               s=12, alpha=0.6, label="Threshold", color="#ff7f0e")
    ax.scatter(plot_df["log10_mu"], plot_df["r_sim_jw"],
               s=12, alpha=0.6, label="JINGWEI", color="#2ca02c")

    ax.set_xlabel("log10(Protein mean intensity)")
    ax.set_ylabel("Missing rate")
    ax.set_title(f"Missing curves: {f.stem}")
    ax.legend(frameon=False)

    plt.tight_layout()
    out_curve = PLOT_DIR / f"{f.stem}_missing_curves.pdf"
    plt.savefig(out_curve)
    plt.close()

    curve_plot_paths.append(out_curve)

    # Cache for heatmap summary
    curve_data[f.stem] = plot_df[["log10_mu", "r_real", "r_sim_logit", "r_sim_thr", "r_sim_jw"]].copy()

res_df = pd.DataFrame(all_results)

if res_df.empty:
    print("No results generated.")
else:
    print("\nSummary results:")
    print(res_df)

    csv_out = PLOT_DIR / "MNAR_simulation_results_summary.csv"
    res_df.to_csv(csv_out, index=False)
    print(f"\nSaved summary CSV to: {csv_out}")

if len(curve_data) > 0:
    methods = [
        ("Real", "r_real"),
        ("Logistic", "r_sim_logit"),
        ("Threshold", "r_sim_thr"),
        ("JINGWEI", "r_sim_jw"),
    ]
    heatmap_pdf = PLOT_DIR / "mnar_missing_heatmaps.pdf"
    plot_missing_heatmap_grid(curve_data, methods, bins=(60, 60), save_path=heatmap_pdf)
    print(f"Saved heatmap PDF to: {heatmap_pdf}")

    print("\nSaved curve PDFs:")
    for p in curve_plot_paths:
        print(f" - {p}")
# Out:
# Loaded 4 datasets.
#
# Missing rate per dataset:
#  - PCSHA: 0.4461
#  - PTV1: 0.6034
#  - TPD: 0.5100
#  - ZZOV: 0.3578
#
# Processing PCSHA.csv ...
#
# Processing PTV1.csv ...
#
# Processing TPD.csv ...
# /home/lizhaoxing/.conda/envs/jingwei/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# Processing ZZOV.csv ...
# /home/lizhaoxing/.conda/envs/jingwei/lib/python3.12/site-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# Summary results:
#   dataset  MAE_logit_mean  MAE_logit_err  RMSE_logit_mean  RMSE_logit_err  \
# 0   PCSHA        0.198070       0.000770         0.254132        0.001329
# 1    PTV1        0.234538       0.000569         0.277409        0.000906
# 2     TPD        0.282403       0.000630         0.324348        0.000911
# ...
